# %%
def factorial(number:int)->int:
    '''
    calculate number! using recursion

    Args:
        number(int): user input the int number

    Return:
        number(int): return the factorial

    Example:
        factorial(4)=24
    '''

    if number==0 :
        return 1
    return number*factorial(number-1)

# %%
factorial(4)
# Out:
# 24

# %%
import math

# %%
def is_prime(number:int)->bool:
    '''
    check if the number is prime or no
    Args:
        number(int): number to check
    Return:
        bool: true if number is prime otherwise false
    Example:
        is_prime(15): returns false

    '''
    for i in range(2,int(math.sqrt(number))+1):
        if number%i==0:
            return False
    return True

# %%
is_prime(15)
# Out:
# False

# %%
def common_divisor(num1:int,num2:int)->list[int]:
    '''
    this function helps to calc the common divisor

    '''
    limit=min(num1,num2)
    divs=[]
    for divisor in range(1,limit+1):
        if num1%divisor==0 and num2%divisor==0:
            divs.append(divisor)
    return divs

# %%
common_divisor(20,10)
# Out:
# [1, 2, 5, 10]

# %%
s='hello depi'
lst= s.split()
print(lst)
new_list=lst[::-1]
print(new_list)
# Out:
# ['hello', 'depi']
# ['depi', 'hello']

# %%
def reverse_string(text:str)->list[str]:
    if not isinstance(text,str):
        raise TypeError('text must be string')
    lst= text.split()
    new_list=lst[::-1]
    return new_list

# %%
user_text=input('please enter the text you want to reverse')
reverse_string(user_text)
# Out:
# ['depi', 'hi']

# %%
def reverse_words(s:str)->str:
    return ' '.join(s.split()[::-1])

# %%
reverse_words('hello Se7a')
# Out:
# 'Se7a hello'

# %%
import random
characters = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
password=''

for _ in range(8):
    password+=random.choice(characters)
print(password)
# Out:
# ZW:vQn{^

# %%
def generate_password(length:int)->str:
    characters = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    password=''
    for _ in range(length):
        password+=random.choice(characters)
    return password

# %%
generate_password(7)
# Out:
# '~7uu}eVN'

# %%
import string
import secrets
def generate_password(length:int)->str:
    characters = (
        string.ascii_letters
        +string.digits
        +string.punctuation)
    return ''.join(secrets.choice(characters) for _ in range(length))

# %%
generate_password(5)
# Out:
# 'U*Bx['

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
result=0
for word in unique_words:
    result += words.count(word)

# %%
def word_freq(lst:list)->dict:
    freq = {}
    for item in lst:
        if item in freq:
            freq[item] += 1
        else:
            freq[item] = 1

    return freq
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
word_freq(words)
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

def chatbot(user_input:str)->str:
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

def main_bot():
    print('chatbot: hi hwo are you')
    while True:
        user_input=input("User: ").lower()
        response=chatbot(user_input)
        print('chatbot: ',response)
        if user_input=="goodbye":
            break

# %%
main_bot()
# Out:
# chatbot: hi hwo are you
# chatbot:  I'm sorry, I didn't understand.
# chatbot:  Farewell!
