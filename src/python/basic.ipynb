# %%
print('hi')
# Out:
# hi

# %%
userName="Abdelmasih"
age=24
course="Python"

print(f"My name is {userName} I am {age} years old course name {course}")
print("My name is {} I am {} years old and this is Depi {} course".format(userName, age, course))
# Out:
# My name is Abdelmasih I am 24 years old course name Python
# My name is Abdelmasih I am 24 years old and this is Depi Python course

# %%
def user_info():
    return f"My name is {userName} and I am {age} years old and this is Depi {course} course"

# %%
print(user_info())
# Out:
# My name is Abdelmasih and I am 24 years old and this is Depi Python course

# %%
print(type(userName))
# Out:
# <class 'str'>

# %%
lst1 = [1, 2, 3, 4, 5]
print(type(lst1))
# Out:
# <class 'list'>

# %%
tupple1 = (1, 2, 3, 4, 5)
print(type(tupple1))
# Out:
# <class 'tuple'>

# %%
tpl2= tuple(lst1)
type(tpl2)
# Out:
# tuple

# %%
set1 = {1, 2, 3, 4, 5}
print(type(set1))
set2 = set(lst1)
print(type(set2))

# %%
dict1 = {'userName': 'Abdelmasih', 'age': 24, 'courseName': 'Python'}
print(type(dict1))
print(dict1['userName'])
# Out:
# <class 'dict'>
# Abdelmasih

# %%
sentence = "Depi for Machine Learning"
type(sentence)
print(sentence[0:3:1])
# Out:
# Dep

# %%
name ="Depi for Machine Learning for all Egyptians"
print(name.upper())
# Out:
# DEPI FOR MACHINE LEARNING FOR ALL EGYPTIANS

# %%
name2=name.replace("all", "")
print(name2)
# Out:
# Depi for Machine Learning for  Egyptians

# %%
name3 = "depi ai"
print(name3.title())
# Out:
# Depi Ai

# %%
name4="Depi for Machine Learning"
name4=name4.split()
print(name4)
# Out:
# ['Depi', 'for', 'Machine', 'Learning']

# %%
new_name = ' '.join(name4)
print(new_name)
# Out:
# Depi for Machine Learning
